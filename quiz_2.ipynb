# %% [markdown]
# <a href="https://colab.research.google.com/github/notice4/google-colab-study/blob/main/quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.src.models import Sequential
from keras.src.layers import Dense
from sklearn.pipeline import Pipeline

# %%
X, y = make_classification(n_samples=3000, n_features=40,
                           n_informative=25, n_redundant=5,
                           n_classes=2, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
pipeline = Pipeline([
    ("step1 - scaler", StandardScaler()),
    ("step2 - pca", PCA(n_components=15))
])

# %%
X_train_pca = pipeline.fit_transform(X_train)
X_test_pca  = pipeline.transform(X_test)

# %%
var_sum = np.sum(pipeline.named_steps["step2 - pca"].explained_variance_ratio_)
print("Ratio:", var_sum)

units = int(var_sum * 100)
print("Units per layer:", units)
# Out:
# Ratio: 0.6204910157268831
# Units per layer: 62

# %%
model = Sequential()
model.add(Dense(units, activation='relu', input_shape=(pca_components,)))

for _ in range(pca_components - 1):
    model.add(Dense(units, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train_pca, y_train,
                    validation_split=0.2, epochs=20,
                    batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6231 - loss: 0.6436 - val_accuracy: 0.7625 - val_loss: 0.5061
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8064 - loss: 0.4225 - val_accuracy: 0.8125 - val_loss: 0.4160
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8445 - loss: 0.3705 - val_accuracy: 0.8188 - val_loss: 0.3991
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8665 - loss: 0.3258 - val_accuracy: 0.8313 - val_loss: 0.3690
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.2853 - val_accuracy: 0.8500 - val_loss: 0.3495
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9179 - loss: 0.2307 - val_accuracy: 0.8583 - val_loss: 0.3528
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9292 - loss: 0.1923 - val_accuracy: 0.8438 - val_loss: 0.3277
# Epoch 8/20
# ...

# %%
train_score = model.evaluate(X_train_pca, y_train, verbose=0)[1]
test_score  = model.evaluate(X_test_pca, y_test, verbose=0)[1]

print("Train Score:", train_score)
print("Validation Score:", test_score)
# Out:
# Train Score: 0.9637500047683716
# Validation Score: 0.8433333039283752
