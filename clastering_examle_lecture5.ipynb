# %% [markdown]
# <a href="https://colab.research.google.com/github/notice4/google-colab-study/blob/main/clastering_examle_lecture5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score



data = pd.read_csv('/content/Mall_Customers.csv')
model = KMeans(n_clusters=5)

data.drop(["CustomerID", "Age"], axis=1, inplace=True)
colors = model.fit_predict(data[['Annual Income (k$)', 'Spending Score (1-100)']])
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]


data.head()
# Out:
#    Gender  Annual Income (k$)  Spending Score (1-100)
# 0    Male                  15                      39
# 1    Male                  15                      81
# 2  Female                  16                       6
# 3  Female                  16                      77
# 4  Female                  17                      40

# %%
plt.scatter(x=data['Annual Income (k$)'], y=data['Spending Score (1-100)'], c=colors)
plt.scatter(x=model.cluster_centers_[:,0], y=model.cluster_centers_[:,1], c='red')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
silhouette_score(X, colors)
# Out:
# np.float64(0.553931997444648)
