# %% [markdown]
# <a href="https://colab.research.google.com/github/notice4/google-colab-study/blob/main/quiz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

data = pd.read_csv('/content/Quiz 1.csv')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data['Electronic Advertising'] = data['Radio'] + data['Newspaper']
data = data.drop(['Radio', 'Newspaper'], axis=1)
display(data.head())
# Out:
#       TV  Sales  Electronic Advertising
# 0  230.1   22.1                   107.0
# 1   44.5   10.4                    84.4
# 2   17.2   12.0                   115.2
# 3  151.5   16.5                    99.8
# 4  180.8   17.9                    69.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TV                      200 non-null    float64
#  1   Sales                   200 non-null    float64
#  2   Electronic Advertising  200 non-null    float64
# dtypes: float64(3)
# memory usage: 4.8 KB

# %%
data.isnull().sum()
# Out:
# TV                        0
# Sales                     0
# Electronic Advertising    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (200, 3)

# %%
y = data['Sales']
X = data.drop('Sales', axis=1)
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
plt.scatter(y, y_pred)
plt.plot([min(y), max(y)], [min(y), max(y)], color='red')
plt.show()

# %%
r2 = r2_score(y, y_pred)
print("R^2:", r2)
# Out:
# R^2: 0.8622532487015777

# %%
y = data['Sales']
X = data.drop('Sales', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
plt.show()

# %%
r2 = r2_score(y_test, y_pred)
print("R^2:", r2)
# Out:
# R^2: 0.892081883848781
