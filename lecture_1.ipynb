# %% [markdown]
# <a href="https://colab.research.google.com/github/notice4/google-colab-study/blob/main/lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
X = df[['Experience Years']].values
y = df['Salary'].values
model.fit(X, y)
print(f'K: {model.coef_}, bias: {model.intercept_}')
# Out:
# K: [9523.65050742], bias: 25673.01576053028

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Experience Years'], df['Salary'])
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.plot(df['Experience Years'], model.predict(X), color='red')
plt.show()
